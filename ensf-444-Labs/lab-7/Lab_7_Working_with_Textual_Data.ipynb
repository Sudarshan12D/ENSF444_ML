# %%
# DataFrame
import pandas as pd

# Matplot
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# Scikit-learn
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer

from sklearn.model_selection import cross_val_predict, StratifiedKFold
from sklearn.feature_selection import SelectKBest, f_classif
from sklearn.linear_model import RidgeClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.svm import SVC
from sklearn.pipeline import Pipeline
from sklearn import metrics

# nltk
import nltk
from nltk.corpus import stopwords
from nltk.stem import SnowballStemmer
from nltk.tokenize import word_tokenize
from nltk.probability import FreqDist
nltk.download('punkt')
import string

# spacy
import spacy
# !python -m spacy download en_core_web_sm

# Word2vec
import gensim

# Utility
import re
import numpy as np
import os
from collections import Counter
import logging
import time
import pickle
import itertools

from wordcloud import WordCloud
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\SUDARSHAN\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# Collecting en-core-web-sm==3.7.1
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.7.1/en_core_web_sm-3.7.1-py3-none-any.whl (12.8 MB)
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      --------------------------------------- 0.0/12.8 MB 129.6 kB/s eta 0:01:39
#      --------------------------------------- 0.0/12.8 MB 129.6 kB/s eta 0:01:39
#      --------------------------------------- 0.0/12.8 MB 145.2 kB/s eta 0:01:28
#      --------------------------------------- 0.0/12.8 MB 150.6 kB/s eta 0:01:25
#      --------------------------------------- 0.1/12.8 MB 204.8 kB/s eta 0:01:03
#      --------------------------------------- 0.1/12.8 MB 425.3 kB/s eta 0:00:30
#      - ------------------------------------- 0.4/12.8 MB 967.1 kB/s eta 0:00:13
#      -- ------------------------------------- 0.9/12.8 MB 2.1 MB/s eta 0:00:06
#      ------ --------------------------------- 2.0/12.8 MB 4.3 MB/s eta 0:00:03
#      ---------- ----------------------------- 3.2/12.8 MB 6.2 MB/s eta 0:00:02
#      -------------- ------------------------- 4.5/12.8 MB 8.0 MB/s eta 0:00:02
#      -------------- ------------------------- 4.7/12.8 MB 8.3 MB/s eta 0:00:01
#      -------------- ------------------------- 4.7/12.8 MB 8.3 MB/s eta 0:00:01
#      -------------- ------------------------- 4.7/12.8 MB 8.3 MB/s eta 0:00:01
#      -------------- ------------------------- 4.7/12.8 MB 8.3 MB/s eta 0:00:01
#      -------------- ------------------------- 4.7/12.8 MB 8.3 MB/s eta 0:00:01
#      -------------------- ------------------- 6.5/12.8 MB 7.7 MB/s eta 0:00:01
#      ------------------------- -------------- 8.2/12.8 MB 9.2 MB/s eta 0:00:01
#      ------------------------------ -------- 10.1/12.8 MB 10.8 MB/s eta 0:00:01
#      ------------------------------------ -- 11.9/12.8 MB 19.3 MB/s eta 0:00:01
#      --------------------------------------  12.8/12.8 MB 19.3 MB/s eta 0:00:01
#      --------------------------------------- 12.8/12.8 MB 17.7 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.8.0,>=3.7.2 in c:\users\sudarshan\anaconda3\envs\ensf-ml\lib\site-packages (from en-core-web-sm==3.7.1) (3.7.4)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\sudarshan\anaconda3\envs\ensf-ml\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\sudarshan\anaconda3\envs\ensf-ml\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\sudarshan\anaconda3\envs\ensf-ml\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\sudarshan\anaconda3\envs\ensf-ml\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\sudarshan\anaconda3\envs\ensf-ml\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in c:\users\sudarshan\anaconda3\envs\ensf-ml\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.2.3)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\sudarshan\anaconda3\envs\ensf-ml\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\sudarshan\anaconda3\envs\ensf-ml\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\sudarshan\anaconda3\envs\ensf-ml\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in c:\users\sudarshan\anaconda3\envs\ensf-ml\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in c:\users\sudarshan\anaconda3\envs\ensf-ml\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.9.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\users\sudarshan\anaconda3\envs\ensf-ml\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (5.2.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\sudarshan\anaconda3\envs\ensf-ml\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.65.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\sudarshan\anaconda3\envs\ensf-ml\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\sudarshan\anaconda3\envs\ensf-ml\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.6.4)
# Requirement already satisfied: jinja2 in c:\users\sudarshan\anaconda3\envs\ensf-ml\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.1.2)
# Requirement already satisfied: setuptools in c:\users\sudarshan\anaconda3\envs\ensf-ml\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (68.2.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\sudarshan\anaconda3\envs\ensf-ml\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (23.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\sudarshan\anaconda3\envs\ensf-ml\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.3.0)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\sudarshan\anaconda3\envs\ensf-ml\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.26.3)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\sudarshan\anaconda3\envs\ensf-ml\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.3 in c:\users\sudarshan\anaconda3\envs\ensf-ml\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.16.3)
# Requirement already satisfied: typing-extensions>=4.6.1 in c:\users\sudarshan\anaconda3\envs\ensf-ml\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\sudarshan\anaconda3\envs\ensf-ml\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sudarshan\anaconda3\envs\ensf-ml\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\sudarshan\anaconda3\envs\ensf-ml\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sudarshan\anaconda3\envs\ensf-ml\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2023.11.17)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\sudarshan\anaconda3\envs\ensf-ml\lib\site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\sudarshan\anaconda3\envs\ensf-ml\lib\site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.1.4)
# Requirement already satisfied: colorama in c:\users\sudarshan\anaconda3\envs\ensf-ml\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\sudarshan\anaconda3\envs\ensf-ml\lib\site-packages (from typer<0.10.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.1.7)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in c:\users\sudarshan\anaconda3\envs\ensf-ml\lib\site-packages (from weasel<0.4.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\sudarshan\anaconda3\envs\ensf-ml\lib\site-packages (from jinja2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.1.3)
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %% [markdown]
# ### Import the dataset and packages
#
# The dataset is downloaded from Kaggle: [link](https://www.kaggle.com/competitions/nlp-getting-started/data?select=train.csv)
#
# You can download it with the following link or download the train.csv file through Kaggle.

# %%
#%%bash
#pip list | grep keras && pip list | grep nltk && pip list | grep spacy

# %%
# !wget -O data.csv https://www.dropbox.com/scl/fi/70e8lr0rsfx5crpmoxj8w/train_ensf.csv?rlkey=4s7p9dpm4fl9hnxiqtrmf2l7z&dl=0
# Out:
# --2024-03-15 11:55:49--  https://www.dropbox.com/scl/fi/70e8lr0rsfx5crpmoxj8w/train_ensf.csv?rlkey=4s7p9dpm4fl9hnxiqtrmf2l7z
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.1.18
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.1.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc679f3d7808f5eded97d2095b1f.dl.dropboxusercontent.com/cd/0/inline/CPKstESPACxOqpDBOQI-K0cv4eGHN7RF_EWjPOG3Azyxufe5MCQfBdOUoTjTmBFkYurMGfD_VbizkqEOo9OL0Nt5NbA1cZc77KeIAjcWDCvjLXH3nAtEvEwuwN9NY3mZTc4RDLposfu6PsVqDAG55PnU/file# [following]
# --2024-03-15 11:55:51--  https://uc679f3d7808f5eded97d2095b1f.dl.dropboxusercontent.com/cd/0/inline/CPKstESPACxOqpDBOQI-K0cv4eGHN7RF_EWjPOG3Azyxufe5MCQfBdOUoTjTmBFkYurMGfD_VbizkqEOo9OL0Nt5NbA1cZc77KeIAjcWDCvjLXH3nAtEvEwuwN9NY3mZTc4RDLposfu6PsVqDAG55PnU/file
# Resolving uc679f3d7808f5eded97d2095b1f.dl.dropboxusercontent.com (uc679f3d7808f5eded97d2095b1f.dl.dropboxusercontent.com)... 162.125.1.15
# Connecting to uc679f3d7808f5eded97d2095b1f.dl.dropboxusercontent.com (uc679f3d7808f5eded97d2095b1f.dl.dropboxusercontent.com)|162.125.1.15|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 987712 (965K) [text/plain]
# Saving to: 'data.csv'
#
#      0K .......... .......... .......... .......... ..........  5% 1014K 1s
#     50K .......... .......... .......... .......... .......... 10% 1.84M 1s
#    100K .......... .......... .......... .......... .......... 15% 4.83M 0s
#    150K .......... .......... .......... .......... .......... 20% 5.05M 0s
#    200K .......... .......... .......... .......... .......... 25% 4.50M 0s
#    250K .......... .......... .......... .......... .......... 31% 3.07M 0s
#    300K .......... .......... .......... .......... .......... 36% 12.4M 0s
#    350K .......... .......... .......... .......... .......... 41% 1.64M 0s
#    400K .......... .......... .......... .......... .......... 46% 7.79M 0s
#    450K .......... .......... .......... .......... .......... 51% 6.47M 0s
#    500K .......... .......... .......... .......... .......... 57% 61.0M 0s
#    550K .......... .......... .......... .......... .......... 62% 13.6M 0s
#    600K .......... .......... .......... .......... .......... 67% 6.28M 0s
#    650K .......... .......... .......... .......... .......... 72% 15.6M 0s
#    700K .......... .......... .......... .......... .......... 77% 3.55M 0s
#    750K .......... .......... .......... .......... .......... 82% 1.60M 0s
#    800K .......... .......... .......... .......... .......... 88% 53.8M 0s
#    850K .......... .......... .......... .......... .......... 93% 47.6M 0s
#    900K .......... .......... .......... .......... .......... 98% 2.74M 0s
#    950K .......... ....                                       100% 67.0M=0.2s
#
# 2024-03-15 11:55:52 (3.77 MB/s) - 'data.csv' saved [987712/987712]
#
# 'dl' is not recognized as an internal or external command,
# operable program or batch file.

# %% [markdown]
# **Task**:
#
# You are predicting whether a given tweet is about a real disaster or not. If so, predict a 1. If not, predict a 0.
#
# **Columns**:
#
# id - a unique identifier for each tweet
#
# text - the text of the tweet
#
# location - the location the tweet was sent from (may be blank)
#
# keyword - a particular keyword from the tweet (may be blank)
#
# target - in train.csv only, this denotes whether a tweet is about a real disaster (1) or not (0)

# %%
# read the dataset
df = pd.read_csv("data.csv")

# %%
# how long is df?
len(df)
# Out:
# 7613

# %%
# look at the head
df.head()
# Out:
#    id keyword location                                               text  \
# 0   1     NaN      NaN  Our Deeds are the Reason of this #earthquake M...
# 1   4     NaN      NaN             Forest fire near La Ronge Sask. Canada
# 2   5     NaN      NaN  All residents asked to 'shelter in place' are ...
# 3   6     NaN      NaN  13,000 people receive #wildfires evacuation or...
# 4   7     NaN      NaN  Just got sent this photo from Ruby #Alaska as ...
#
#    target
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
# find the unique values in target
df.target.unique()
# Out:
# array([1, 0], dtype=int64)

# %%
# create a column that has the name of the label instead of its digit call it label
decode_map = {0: "not_disasterous", 1: "disasterous"}
def decode_sentiment(label):
    return decode_map[int(label)]

df.loc[:, 'label'] = df.target.apply(lambda x: decode_sentiment(x))

# %%
# check the null values
print('null values of each field:\n', df.isnull().sum())
# Out:
# null values of each field:
#  id             0
# keyword       61
# location    2533
# text           0
# target         0
# label          0
# dtype: int64

# %%
# fill keyword and location with 'no_key' and 'no_location'
df.keyword.fillna('no_keyword', inplace = True)
df.location.fillna('no_location', inplace = True)

# %%
# visualize the number of negative and positive examples
target_cnt = Counter(df.target)

plt.figure(figsize=(16,8))
plt.bar(target_cnt.keys(), target_cnt.values())
plt.title("Dataset labels distribuition")
# Out:
# Text(0.5, 1.0, 'Dataset labels distribuition')

# %%
# what are the top 30 locations in the dataset

top_30 = df.groupby(['location']).count().text.sort_values(ascending = False)[:30]

# plot the top 30

plt.figure(figsize = (6,10))
sns.barplot(x = top_30, y = top_30.index);
plt.xlabel('number of tweets');

# %% [markdown]
# ### Preprocessing

# %%
def preprocess(text:str) -> str:

    # lower case the words
    text = text.lower()

    # remove hyperlinks
    text = re.sub(r"\S*https?:\S*", "", text)

    # remove mentions and hashtags
    text = re.sub(r'[@#]\w*\_*' , '', text)

    # substitute patterns with their correct representation to remove
    rep_character_entity_refrences = {"&gt;": ">", "&lt;":"<",
                                      "&amp;": "&"}

    for k,v in rep_character_entity_refrences.items():
        text = re.sub(k, v, text)

    return text

df.loc[:, 'cleaned_text'] = df.loc[:, 'text'].apply(lambda x: preprocess(x))

# %%
df
# Out:
#          id     keyword     location  \
# 0         1  no_keyword  no_location
# 1         4  no_keyword  no_location
# 2         5  no_keyword  no_location
# 3         6  no_keyword  no_location
# 4         7  no_keyword  no_location
# ...     ...         ...          ...
# 7608  10869  no_keyword  no_location
# 7609  10870  no_keyword  no_location
# 7610  10871  no_keyword  no_location
# 7611  10872  no_keyword  no_location
# 7612  10873  no_keyword  no_location
#
#                                                    text  target        label  \
# 0     Our Deeds are the Reason of this #earthquake M...       1  disasterous
# 1                Forest fire near La Ronge Sask. Canada       1  disasterous
# 2     All residents asked to 'shelter in place' are ...       1  disasterous
# 3     13,000 people receive #wildfires evacuation or...       1  disasterous
# 4     Just got sent this photo from Ruby #Alaska as ...       1  disasterous
# ...                                                 ...     ...          ...
# 7608  Two giant cranes holding a bridge collapse int...       1  disasterous
# 7609  @aria_ahrary @TheTawniest The out of control w...       1  disasterous
# 7610  M1.94 [01:04 UTC]?5km S of Volcano Hawaii. htt...       1  disasterous
# 7611  Police investigating after an e-bike collided ...       1  disasterous
# 7612  The Latest: More Homes Razed by Northern Calif...       1  disasterous
#
#                                            cleaned_text
# 0     our deeds are the reason of this  may allah fo...
# 1                forest fire near la ronge sask. canada
# 2     all residents asked to 'shelter in place' are ...
# 3     13,000 people receive  evacuation orders in ca...
# 4     just got sent this photo from ruby  as smoke f...
# ...                                                 ...
# 7608  two giant cranes holding a bridge collapse int...
# 7609    the out of control wild fires in california ...
# 7610        m1.94 [01:04 utc]?5km s of volcano hawaii.
# 7611  police investigating after an e-bike collided ...
# 7612  the latest: more homes razed by northern calif...
#
# [7613 rows x 7 columns]

# %% [markdown]
# NLTK (Natural Language Toolkit) and spaCy are two popular libraries used for NLP tasks in Python.
#
# They both provide lists of stopwords for various languages, including English.
#
# stopwords are common words that are often filtered out from text during preprocessing because they are considered to have little or no significance. Examples of NLTK English stopwords include "the," "is," "and," "but," etc.

# %%
# nltk stopwords
nltk.download('stopwords')
nltk_stopwords = stopwords.words('english')

# spacy stopwords
nlp = spacy.load("en_core_web_sm")
spacy_stopwords = list(nlp.Defaults.stop_words.copy())

words_to_remove =  ['absolutely', "actually"]

all_stopwords = set(
    nltk_stopwords + spacy_stopwords + words_to_remove
    )

def remove_st(text:str) -> str:

    # Remove stopwords
    filtered_words = [word for word in text.split() if word not in all_stopwords]

    # Join the filtered words back into a sentence
    filtered_text = ' '.join(filtered_words)

    return filtered_text

# apply the remove st on cleaned_text
df.loc[:, 'cleaned_text_no_st'] = df.loc[:, 'cleaned_text'].apply(lambda x: remove_st(x))
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\SUDARSHAN\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
df
# Out:
#          id     keyword     location  \
# 0         1  no_keyword  no_location
# 1         4  no_keyword  no_location
# 2         5  no_keyword  no_location
# 3         6  no_keyword  no_location
# 4         7  no_keyword  no_location
# ...     ...         ...          ...
# 7608  10869  no_keyword  no_location
# 7609  10870  no_keyword  no_location
# 7610  10871  no_keyword  no_location
# 7611  10872  no_keyword  no_location
# 7612  10873  no_keyword  no_location
#
#                                                    text  target        label  \
# 0     Our Deeds are the Reason of this #earthquake M...       1  disasterous
# 1                Forest fire near La Ronge Sask. Canada       1  disasterous
# 2     All residents asked to 'shelter in place' are ...       1  disasterous
# 3     13,000 people receive #wildfires evacuation or...       1  disasterous
# 4     Just got sent this photo from Ruby #Alaska as ...       1  disasterous
# ...                                                 ...     ...          ...
# 7608  Two giant cranes holding a bridge collapse int...       1  disasterous
# 7609  @aria_ahrary @TheTawniest The out of control w...       1  disasterous
# 7610  M1.94 [01:04 UTC]?5km S of Volcano Hawaii. htt...       1  disasterous
# 7611  Police investigating after an e-bike collided ...       1  disasterous
# 7612  The Latest: More Homes Razed by Northern Calif...       1  disasterous
#
#                                            cleaned_text  \
# 0     our deeds are the reason of this  may allah fo...
# 1                forest fire near la ronge sask. canada
# 2     all residents asked to 'shelter in place' are ...
# 3     13,000 people receive  evacuation orders in ca...
# 4     just got sent this photo from ruby  as smoke f...
# ...                                                 ...
# 7608  two giant cranes holding a bridge collapse int...
# 7609    the out of control wild fires in california ...
# 7610        m1.94 [01:04 utc]?5km s of volcano hawaii.
# 7611  police investigating after an e-bike collided ...
# 7612  the latest: more homes razed by northern calif...
#
#                                      cleaned_text_no_st
# 0                            deeds reason allah forgive
# 1                forest fire near la ronge sask. canada
# 2     residents asked 'shelter place' notified offic...
# 3     13,000 people receive evacuation orders califo...
# 4                got sent photo ruby smoke pours school
# ...                                                 ...
# 7608  giant cranes holding bridge collapse nearby homes
# 7609  control wild fires california northern state. ...
# 7610              m1.94 [01:04 utc]?5km volcano hawaii.
# 7611  police investigating e-bike collided car littl...
# 7612  latest: homes razed northern california wildfi...
#
# [7613 rows x 8 columns]

# %%
def remove_punctuation_and_digits(text:str) -> str:

    # Remove punctuations
    text = re.sub(r'[^\w\s]', '', text)

    # Remove digits
    text = re.sub(r'\d', '', text)

    # removes all single letters surrounded with space except letters I and a
    text = re.sub(r'(?:^|\s)(?![ia])[a-z] +', ' ', text)

    return text

# %%
df.loc[:, 'cleaned_text'] = df.loc[:, 'cleaned_text'].apply(lambda x: remove_punctuation_and_digits(x))
df.loc[:, 'cleaned_text_no_st'] = df.loc[:, 'cleaned_text_no_st'].apply(lambda x: remove_punctuation_and_digits(x))

# %%
df
# Out:
#          id     keyword     location  \
# 0         1  no_keyword  no_location
# 1         4  no_keyword  no_location
# 2         5  no_keyword  no_location
# 3         6  no_keyword  no_location
# 4         7  no_keyword  no_location
# ...     ...         ...          ...
# 7608  10869  no_keyword  no_location
# 7609  10870  no_keyword  no_location
# 7610  10871  no_keyword  no_location
# 7611  10872  no_keyword  no_location
# 7612  10873  no_keyword  no_location
#
#                                                    text  target        label  \
# 0     Our Deeds are the Reason of this #earthquake M...       1  disasterous
# 1                Forest fire near La Ronge Sask. Canada       1  disasterous
# 2     All residents asked to 'shelter in place' are ...       1  disasterous
# 3     13,000 people receive #wildfires evacuation or...       1  disasterous
# 4     Just got sent this photo from Ruby #Alaska as ...       1  disasterous
# ...                                                 ...     ...          ...
# 7608  Two giant cranes holding a bridge collapse int...       1  disasterous
# 7609  @aria_ahrary @TheTawniest The out of control w...       1  disasterous
# 7610  M1.94 [01:04 UTC]?5km S of Volcano Hawaii. htt...       1  disasterous
# 7611  Police investigating after an e-bike collided ...       1  disasterous
# 7612  The Latest: More Homes Razed by Northern Calif...       1  disasterous
#
#                                            cleaned_text  \
# 0     our deeds are the reason of this  may allah fo...
# 1                 forest fire near la ronge sask canada
# 2     all residents asked to shelter in place are be...
# 3      people receive  evacuation orders in california
# 4     just got sent this photo from ruby  as smoke f...
# ...                                                 ...
# 7608  two giant cranes holding a bridge collapse int...
# 7609    the out of control wild fires in california ...
# 7610                           utckm of volcano hawaii
# 7611  police investigating after an ebike collided w...
# 7612  the latest more homes razed by northern califo...
#
#                                      cleaned_text_no_st
# 0                            deeds reason allah forgive
# 1                 forest fire near la ronge sask canada
# 2     residents asked shelter place notified officer...
# 3           people receive evacuation orders california
# 4                got sent photo ruby smoke pours school
# ...                                                 ...
# 7608  giant cranes holding bridge collapse nearby homes
# 7609  control wild fires california northern state t...
# 7610                               utckm volcano hawaii
# 7611  police investigating ebike collided car little...
# 7612  latest homes razed northern california wildfir...
#
# [7613 rows x 8 columns]

# %% [markdown]
# A word cloud is a visual representation of text data, where the size of each word indicates its frequency or importance in the text.
#
# Word clouds are often used to quickly and visually summarize the content of a large amount of text data.
#
# They can help identify common themes, topics, or keywords within the text.

# %%
# build a word cloud for target == 0

# Combine all text from the specified column into a single string
text = ' '.join(df[df.target==0]['cleaned_text_no_st'])

# Generate the word cloud
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text)

# Display the word cloud using matplotlib
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')  # Turn off axis labels
plt.show()

# %%
# build a word cloud for target == 1

# Combine all text from the specified column into a single string
text = ' '.join(df[df.target==1]['cleaned_text_no_st'])

# Generate the word cloud
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text)

# Display the word cloud using matplotlib
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')  # Turn off axis labels
plt.show()

# %% [markdown]
# Tokenizing is the process of breaking down a text into smaller units, such as words or sentences, called tokens.
#
# Tokenization is an essential step in NLP tasks because it allows the text to be processed at a more granular level.

# %%
# view the most frequent words for target == 1

# Tokenize the text in the specified column
tokens = []
for text in df[df.target==1]['cleaned_text_no_st']:
    tokens.extend(word_tokenize(text))

# Calculate the frequency distribution of tokens
freq_dist = FreqDist(tokens)

# Display the most frequent words and their counts
most_common_words = freq_dist.most_common(10)
print("Most frequent words:")
for word, count in most_common_words:
    print(f"{word}: {count}")

# Plot a bar chart of the frequency distribution
freq_dist.plot(20, cumulative=False)
plt.show()
# Out:
# Most frequent words:
# fire: 177
# suicide: 110
# disaster: 110
# california: 107
# police: 106
# people: 104
# killed: 92
# like: 92
# pm: 89
# fires: 85

# %% [markdown]
# ### Prediction with RidgeClassifier, NaiveBayes, LinearSVM
# Here we'll use counter vectorizer to specify one column for each word in the tweets and use it as a feature for prediction. If a tweet has a word, the column specife to that word will have the value of 1 (or more based on how many times that word has repeated in that tweet.)
#
# As for the models, we chose these three because they can predict sparse data fast. You can go on and do gridsearch on them and find the best parameters for each.

# %%
# create a CountVectorizer function
counter_vectorizer = CountVectorizer()

# fit and transform the df
counter_vectorizer.fit(df.cleaned_text_no_st)
transformed_rows = counter_vectorizer.transform(df.cleaned_text_no_st).todense()

# %%
transformed_rows.shape
# Out:
# (7613, 13691)

# %%
# # use the three algorithms and build cross validation to assess their performance
# # make sure to create one pipeline with a feature selection algorithm inside it as well
# import warnings
# warnings.filterwarnings("ignore", message="Features.*", category=UserWarning)
# warnings.filterwarnings("ignore", message="invalid.*", category=RuntimeWarning)

# # Assuming you have your target variable 'y' and features 'transformed_rows'
# # Example data
# np.random.seed(42)
# X = np.asarray(transformed_rows)
# y = df.target
# # y = df.target.values.reshape(-1, 1)

# # Create a pipeline with feature selection and classifiers
# ridge_pipeline = Pipeline([
#     ('feature_selection', SelectKBest(f_classif, k=100)),  # Adjust k as needed
#     ('classifier', RidgeClassifier())
# ])

# naive_bayes_pipeline = Pipeline([
#     ('feature_selection', SelectKBest(f_classif, k=100)),
#     ('classifier', MultinomialNB())
# ])

# linear_svm_pipeline = Pipeline([
#     ('feature_selection', SelectKBest(f_classif, k=100)),
#     ('classifier', SVC(kernel='linear'))
# ])

# # Define the classifiers
# classifiers = {
#     'Ridge Classifier': ridge_pipeline,
#     'Naive Bayes': naive_bayes_pipeline,
#     'Linear SVM': linear_svm_pipeline
# }

# # Perform cross-validation and compare results
# cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

# for name, clf in classifiers.items():
#     y_pred = cross_val_predict(clf, X, y, cv=cv)

#     # Print confusion matrix and metrics
#     print(f'\nResults for {name}:')
#     print('Confusion Matrix:')
#     print(metrics.confusion_matrix(y, y_pred))

#     accuracy = metrics.accuracy_score(y, y_pred)
#     precision = metrics.precision_score(y, y_pred)
#     recall = metrics.recall_score(y, y_pred)
#     f1 = metrics.f1_score(y, y_pred)

#     print(f'Accuracy: {accuracy:.2f}')
#     print(f'Precision: {precision:.2f}')
#     print(f'Recall: {recall:.2f}')
#     print(f'F1 Score: {f1:.2f}')

# %% [markdown]
# ***Your Turn***

# %% [markdown]
# The dataset is downloaded from Kaggle: [link](https://www.kaggle.com/datasets/emineyetm/fake-news-detection-datasets)

# %%
df_true = pd.read_csv('./True.csv', encoding='utf-8')
df_fake = pd.read_csv('./Fake.csv', encoding='utf-8')

df_fake["target"] = 0
df_true["target"] = 1

df = pd.concat([df_fake,df_true], axis = 0).drop(["title", "subject","date"], axis = 1).sample(frac = 1)

df.isnull().sum()
# Out:
# text      0
# target    0
# dtype: int64

# %%
df = df.reset_index(drop=True)
df.head()
# Out:
#                                                 text  target
# 0  LONDON (Reuters) - Britain s government said o...       1
# 1  WASHINGTON (Reuters) - Director of National In...       1
# 2  Former Navy SEAL and GOP Rep. Scott Taylor, R-...       0
# 3  WASHINGTON (Reuters) - The White House on Thur...       1
# 4  BERN (Reuters) - European and African minister...       1

# %%
import re

def preprocess(text:str) -> str:

    # lower case the words
    text = text.lower()
    
    # remove hyperlinks
    text = re.sub(r"\S*https?:\S*", "", text)
    
    # remove mentions and hashtags
    text = re.sub(r'[@#]\w*\_*' , '', text)
    
    # substitute patterns with their correct representation to remove
    rep_character_entity_refrences = {"&gt;": ">", "&lt;":"<",
                                      "&amp;": "&"}

    for k,v in rep_character_entity_refrences.items():
        text = re.sub(k, v, text)
    
    return text

# %%
# nltk stopwords
nltk.download('stopwords')
nltk_stopwords = stopwords.words('english')

# spacy stopwords
nlp = spacy.load("en_core_web_sm")
spacy_stopwords = list(nlp.Defaults.stop_words.copy())


words_to_remove =  ['absolutely', "actually"]

all_stopwords = set(
    nltk_stopwords + spacy_stopwords + words_to_remove
    )

def remove_st(text:str) -> str:

    # Remove stopwords
    filtered_words = [word for word in text.split() if word not in all_stopwords]
    
    # Join the filtered words back into a sentence
    filtered_text = ' '.join(filtered_words)

    return filtered_text
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\SUDARSHAN\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
def remove_punctuation_and_digits(text:str) -> str:

    # Remove punctuations
    text = re.sub(r'[^\w\s]', '', text)
    
    # Remove digits
    text = re.sub(r'\d+', '', text)
    
    # removes all single letters surrounded with space except letters I and a
    text = re.sub(r'(?:^|\s)(?![ia])[a-z] +', ' ', text)
    
    return text

# %%
# apply preprocessing function
df.loc[:, 'cleaned_text'] = df.loc[:, 'text'].apply(lambda x: preprocess(x))

# apply the remove st on cleaned_text
df.loc[:, 'cleaned_text_no_st'] = df.loc[:, 'cleaned_text'].apply(lambda x: remove_st(x))

# remove punctuation and digits
df.loc[:, 'cleaned_text'] = df.loc[:, 'cleaned_text'].apply(lambda x: remove_punctuation_and_digits(x))
df.loc[:, 'cleaned_text_no_st'] = df.loc[:, 'cleaned_text_no_st'].apply(lambda x: remove_punctuation_and_digits(x))

# %%
# build a word cloud for target == 0

# Combine all text from the specified column into a single string
text = " ".join(df[df['target'] == 0]['cleaned_text_no_st'])

# Generate the word cloud
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text)

# Display the word cloud using matplotlib
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')  # Turn off axis labels
plt.show()

# %%
# view the most frequent words for target == 1

# Tokenize the text in the specified column
tokens = []
for text in df[df.target==1]['cleaned_text_no_st']:
    tokens.extend(word_tokenize(text))
    
# Calculate the frequency distribution of tokens
freq_dist = FreqDist(tokens)

# Display the most frequent words and their counts
most_common_words = freq_dist.most_common(10)
print("Most frequent words:")
for word, count in most_common_words:
    print(f"{word}: {count}")
    
# Plot a bar chart of the frequency distribution
freq_dist.plot(20, cumulative=False)
plt.show()
# Out:
# Most frequent words:
# said: 99039
# trump: 42595
# us: 39395
# reuters: 28404
# president: 25548
# state: 18757
# government: 17980
# states: 17638
# new: 16786
# house: 16407

# %%
CV = CountVectorizer(max_features=15000, dtype=np.int32)

# fit and transform the df
CV.fit(df.cleaned_text_no_st)
transformed_rows = CV.transform(df.cleaned_text_no_st).todense()

# %%
transformed_rows.shape
# Out:
# (44898, 15000)

# %%
# use the three algorithms and build cross validation to assess their performance
# make sure to create one pipeline with a feature selection algorithm inside it as well
import warnings
from sklearn.exceptions import DataConversionWarning
warnings.filterwarnings("ignore", message="Features.*", category=UserWarning)
warnings.filterwarnings("ignore", message="invalid.*", category=RuntimeWarning)
warnings.filterwarnings("ignore", message="A column.*", category=DataConversionWarning)

# Assuming you have your target variable 'y' and features 'transformed_rows'
# Example data
np.random.seed(42)
X = np.asarray(transformed_rows)
y = df.target.values.reshape(-1, 1)

# Create a pipeline with feature selection and classifiers
ridge_pipeline = Pipeline([
    ('feature_selection', SelectKBest(f_classif, k=100)),  # Adjust k as needed
    ('classifier', RidgeClassifier())
])

naive_bayes_pipeline = Pipeline([
    ('feature_selection', SelectKBest(f_classif, k=100)),
    ('classifier', MultinomialNB())
])

linear_svm_pipeline = Pipeline([
    ('feature_selection', SelectKBest(f_classif, k=100)),
    ('classifier', SVC(kernel='linear'))
])

# Define the classifiers
classifiers = {
    'Ridge Classifier': ridge_pipeline,
    'Naive Bayes': naive_bayes_pipeline,
    'Linear SVM': linear_svm_pipeline
}

# Perform cross-validation and compare results
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

for name, clf in classifiers.items():
    y_pred = cross_val_predict(clf, X, y, cv=cv)

    # Print confusion matrix and metrics
    print(f'\nResults for {name}:')
    print('Confusion Matrix:')
    print(metrics.confusion_matrix(y, y_pred))

    accuracy = metrics.accuracy_score(y, y_pred)
    precision = metrics.precision_score(y, y_pred)
    recall = metrics.recall_score(y, y_pred)
    f1 = metrics.f1_score(y, y_pred)

    print(f'Accuracy: {accuracy:.2f}')
    print(f'Precision: {precision:.2f}')
    print(f'Recall: {recall:.2f}')
    print(f'F1 Score: {f1:.2f}')
# Out:
# Results for Ridge Classifier:
# Confusion Matrix:
# [[23233   248]
#  [  195 21222]]
# Accuracy: 0.99
# Precision: 0.99
# Recall: 0.99
# F1 Score: 0.99
#
# Results for Naive Bayes:
# Confusion Matrix:
# [[21804  1677]
#  [  186 21231]]
# Accuracy: 0.96
# Precision: 0.93
# Recall: 0.99
# F1 Score: 0.96
#
# Results for Linear SVM:
# Confusion Matrix:
# [[23339   142]
#  [   46 21371]]
# Accuracy: 1.00
# Precision: 0.99
# Recall: 1.00
# F1 Score: 1.00
